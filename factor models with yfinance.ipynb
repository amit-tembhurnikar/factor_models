# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import linregress
from statsmodels.api import OLS, add_constant
import streamlit as st

# === Parameters ===
START_DATE = "2005-12-31"
END_DATE = "2025-07-31"
REBALANCE_MONTHS = [3, 6, 9, 12]  # Quarterly

# Step 1: Load NSE500 list
nse500 = pd.read_html("https://en.wikipedia.org/wiki/NIFTY_50", header=0)[1]
symbols = nse500['Symbol'].tolist()

# Step 2: Download adjusted close daily price history
data = {}
for symbol in tqdm(symbols):
    try:
        df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False, auto_adjust=True)
        if df.empty or 'Close' not in df.columns:
            continue
        df = df[['Close']].rename(columns={'Close': symbol})
        data[symbol] = df
    except:
        continue

if not data:
    st.error("No data downloaded from yfinance. Check your internet connection or ticker symbols.")
    st.stop()

prices = pd.concat(data.values(), axis=1)
prices.columns = data.keys()

prices.index = pd.to_datetime(prices.index)
prices = prices.dropna(axis=1, how='all')

# === Calculate Barra-style factors ===
log_returns = np.log(prices / prices.shift(1))
monthly_prices = prices.resample('Q').last()

factor_data = {}
for date in monthly_prices.index[4:]:
    current_prices = monthly_prices.loc[date]
    past_prices = monthly_prices.loc[date - pd.DateOffset(months=4)]
    returns_12m = (current_prices / past_prices) - 1

    size = np.log(current_prices)
    momentum = returns_12m
    volatility = log_returns.loc[:date].rolling(252).std().iloc[-1]

    # Placeholder for value/growth (replace with real fundamentals later)
    value = pd.Series(np.random.normal(0, 1, len(current_prices)), index=current_prices.index)
    growth = pd.Series(np.random.normal(0, 1, len(current_prices)), index=current_prices.index)

    factors = pd.DataFrame({
        'Size': size,
        'Momentum': momentum,
        'Volatility': volatility,
        'Value': value,
        'Growth': growth
    })
    factor_data[date] = factors

# === Backtest each factor ===
def backtest_factor(factor_name):
    factor_returns = []
    for i, date in enumerate(factor_data.keys()):
        if date.month not in REBALANCE_MONTHS:
            continue
        df = factor_data[date].dropna()
        if len(df) < 10:
            continue

        top = df[factor_name].nlargest(int(len(df)*0.1)).index
        bottom = df[factor_name].nsmallest(int(len(df)*0.1)).index

        try:
            next_date = list(factor_data.keys())[i+1]
        except IndexError:
            break

        try:
            future_prices = monthly_prices.loc[next_date]
            curr_prices = monthly_prices.loc[date]

            top_ret = (future_prices[top] / curr_prices[top] - 1).mean()
            bottom_ret = (future_prices[bottom] / curr_prices[bottom] - 1).mean()
            factor_returns.append((next_date, top_ret, bottom_ret))
        except:
            continue

    df = pd.DataFrame(factor_returns, columns=["Date", "Top", "Bottom"]).set_index("Date")
    df["Top_Cumulative"] = (1 + df["Top"]).cumprod()
    df["Bottom_Cumulative"] = (1 + df["Bottom"]).cumprod()
    return df

# === Run backtests ===
factors = ['Size', 'Momentum', 'Volatility', 'Value', 'Growth']
results = {factor: backtest_factor(factor) for factor in factors}

# === Benchmark ===
benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
benchmark_ret = benchmark.pct_change().dropna()
benchmark_cum = (1 + benchmark_ret).cumprod()

# === Plot Streamlit Outputs ===
st.title("📈 Barra Factor Strategy Backtests")
for factor in factors:
    df = results[factor]
    st.subheader(f"{factor} Factor")
    st.line_chart(df[["Top_Cumulative", "Bottom_Cumulative"]].join(benchmark_cum.rename("Nifty 50"), how="inner"))
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.82it/s]
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\4274677729.py:43: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   monthly_prices = prices.resample('Q').last()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1164844800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2006-11-30 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\datetimes.py:630, in DatetimeIndex.get_loc(self, key)
#     629 try:
# --> 630     return Index.get_loc(self, key)
#     631 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: Timestamp('2006-11-30 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 48
#      46 for date in monthly_prices.index[4:]:
#      47     current_prices = monthly_prices.loc[date]
# ---> 48     past_prices = monthly_prices.loc[date - pd.DateOffset(months=4)]
#      49     returns_12m = (current_prices / past_prices) - 1
#      51     size = np.log(current_prices)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\datetimes.py:632, in DatetimeIndex.get_loc(self, key)
#     630     return Index.get_loc(self, key)
#     631 except KeyError as err:
# --> 632     raise KeyError(orig_key) from err
#
# KeyError: Timestamp('2006-11-30 00:00:00')

# %%
monthly_prices
# Out:
#                ADANIENT   ADANIPORTS   APOLLOHOSP   ASIANPAINT     AXISBANK  \
# Date
# 2006-03-31     3.575901          NaN   225.542419    52.684460    62.256199
# 2006-06-30     7.764215          NaN   178.413467    49.007195    47.330540
# 2006-09-30     8.271670          NaN   214.187653    55.964470    66.981674
# 2006-12-31    14.018536          NaN   193.218872    61.452759    82.949883
# 2007-03-31    13.098175          NaN   225.825226    64.230721    86.623985
# ...                 ...          ...          ...          ...          ...
# 2024-09-30  3134.247559  1441.188354  7188.981934  3293.021484  1231.147827
# 2024-12-31  2527.357666  1225.139404  7286.044922  2260.494385  1063.790771
# 2025-03-31  2314.616455  1177.222534  6616.200195  2319.251953  1101.058960
# 2025-06-30  2619.399902  1450.199951  7242.000000  2341.100098  1198.175903
# 2025-09-30  2596.100098  1443.099976  7303.500000  2382.399902  1099.300049
#
#               BAJAJ-AUTO  BAJFINANCE   BAJAJFINSV         BEL   BHARTIARTL  \
# Date
# 2006-03-31    430.028259    4.531797  2688.238770    9.735339   170.971542
# 2006-06-30    430.419647    3.489977  2690.685791    7.874147   153.263412
# 2006-09-30    469.198334    3.301971  2933.104004    8.588296   194.375229
# 2006-12-31    410.125885    3.394398  2563.822754    9.986594   260.941284
# 2007-03-31    380.131561    3.940432  2376.319824   11.192182   316.426880
# ...                  ...         ...          ...         ...          ...
# 2024-09-30  12040.789062  766.617554  1972.439087  283.529663  1695.376831
# 2024-12-31   8581.120117  679.038208  1567.336304  291.535309  1574.586670
# 2025-03-31   7684.104492  890.283508  2006.372437  301.320007  1719.029175
# 2025-06-30   8376.000000  936.500000  2056.000000  421.500000  1992.939209
# 2025-09-30   8347.500000  942.000000  2029.599976  394.750000  1901.000000
#
#             ...    SUNPHARMA          TCS   TATACONSUM  TATAMOTORS  \
# Date        ...
# 2006-03-31  ...    69.344307   179.003906    63.433384  152.469009
# 2006-06-30  ...    63.547821   162.960434    56.042950  132.256561
# 2006-09-30  ...    75.617874   191.880600    55.787903  143.379852
# 2006-12-31  ...    79.758629   230.052780    53.627918  149.852478
# 2007-03-31  ...    86.401077   232.821686    45.158981  121.166557
# ...         ...          ...          ...          ...         ...
# 2024-09-30  ...  1908.874146  4196.322754  1188.144165  966.341614
# 2024-12-31  ...  1868.897583  4035.380859   907.970642  733.840576
# 2025-03-31  ...  1729.008301  3562.290283   994.529175  668.700623
# 2025-06-30  ...  1670.201904  3450.290771  1098.900024  688.000000
# 2025-09-30  ...  1693.599976  3189.899902  1095.900024  680.250000
#
#              TATASTEEL        TECHM        TITAN        TRENT    ULTRACEMCO  \
# Date
# 2006-03-31   26.802870          NaN    37.649734    65.315193    626.643921
# 2006-06-30   27.349739          NaN    26.776594    50.368542    685.955322
# 2006-09-30   27.452240   122.518303    36.487278    63.728863    820.937012
# 2006-12-31   21.846991   331.368103    38.893372    63.833435   1011.193909
# 2007-03-31   20.370466   283.034180    38.117722    49.255703    713.786804
# ...                ...          ...          ...          ...           ...
# 2024-09-30  164.708893  1535.110352  3812.476318  7568.093262  11802.000000
# 2024-12-31  134.903961  1675.584473  3243.388916  7117.184082  11426.349609
# 2025-03-31  150.725006  1392.801392  3054.158691  5320.540527  11509.549805
# 2025-06-30  159.759995  1656.729004  3679.127686  6217.500000  12093.000000
# 2025-09-30  162.369995  1548.900024  3402.899902  5375.000000  12498.000000
#
#                  WIPRO
# Date
# 2006-03-31   56.808010
# 2006-06-30   52.647324
# 2006-09-30   53.831848
# 2006-12-31   62.138920
# 2007-03-31   57.854351
# ...                ...
# 2024-09-30  265.450287
# 2024-12-31  295.968842
# 2025-03-31  262.250000
# 2025-06-30  265.980011
# 2025-09-30  266.950012
#
# [79 rows x 50 columns]

# %%
volatility
# Out:
# ADANIENT      0.041012
# ADANIPORTS    0.046046
# APOLLOHOSP    0.025978
# ASIANPAINT    0.024922
# AXISBANK      0.045694
# BAJAJ-AUTO    0.051255
# BAJFINANCE    0.043049
# BAJAJFINSV    0.181911
# BEL           0.031888
# BHARTIARTL    0.033457
# CIPLA         0.025520
# COALINDIA          NaN
# DRREDDY       0.028560
# EICHERMOT     0.041772
# ETERNAL            NaN
# GRASIM        0.031553
# HCLTECH       0.045754
# HDFCBANK      0.036310
# HDFCLIFE           NaN
# HEROMOTOCO    0.026118
# HINDALCO      0.047728
# HINDUNILVR    0.026320
# ICICIBANK     0.050151
# INDUSINDBK    0.049171
# INFY          0.031045
# ITC           0.025997
# JIOFIN             NaN
# JSWSTEEL      0.052529
# KOTAKBANK     0.050845
# LT            0.037526
# M&M           0.041211
# MARUTI        0.031075
# NESTLEIND     0.000000
# NTPC          0.033542
# ONGC          0.033419
# POWERGRID     0.037856
# RELIANCE      0.040247
# SBILIFE            NaN
# SHRIRAMFIN    0.027788
# SBIN          0.036909
# SUNPHARMA     0.028031
# TCS           0.036394
# TATACONSUM    0.028417
# TATAMOTORS    0.041519
# TATASTEEL     0.048062
# TECHM         0.042438
# TITAN         0.042100
# TRENT         0.026751
# ULTRACEMCO    0.031996
# WIPRO         0.038205
# Name: 2009-01-30 00:00:00, dtype: float64

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import linregress
from statsmodels.api import OLS, add_constant
import streamlit as st

# === Parameters ===
START_DATE = "2005-12-31"
END_DATE = "2025-07-31"
REBALANCE_MONTHS = [3, 6, 9, 12]  # Quarterly

# Step 1: Load NSE500 list
nse500 = pd.read_html("https://en.wikipedia.org/wiki/NIFTY_50", header=0)[1]
symbols = nse500['Symbol'].tolist()

# Step 2: Download adjusted close daily price history
data = {}
for symbol in tqdm(symbols):
    try:
        df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
        if df.empty or 'Close' not in df.columns:
            continue
        df = df[['Close']].rename(columns={'Close': symbol})
        data[symbol] = df
    except:
        continue

if not data:
    st.error("No data downloaded from yfinance. Check your internet connection or ticker symbols.")
    st.stop()

prices = pd.concat(data.values(), axis=1)
prices.columns = data.keys()

prices.index = pd.to_datetime(prices.index)
prices = prices.dropna(axis=1, how='all')

# === Calculate Barra-style factors ===
log_returns = np.log(prices / prices.shift(1))
monthly_prices = prices.resample('M').last()

factor_data = {}
for date in monthly_prices.index[12:]:
    try:
        current_prices = monthly_prices.loc[date]
        past_prices = monthly_prices.shift(12).loc[date]
        returns_12m = (current_prices / past_prices) - 1

        size = np.log(current_prices)
        momentum = returns_12m
        volatility = log_returns.loc[:date].rolling(252).std().iloc[-1]

        # Placeholder for value/growth (replace with real fundamentals later)
        value = pd.Series(np.random.normal(0, 1, len(current_prices)), index=current_prices.index)
        growth = pd.Series(np.random.normal(0, 1, len(current_prices)), index=current_prices.index)

        factors = pd.DataFrame({
            'Size': size,
            'Momentum': momentum,
            'Volatility': volatility,
            'Value': value,
            'Growth': growth
        })
        factor_data[date] = factors
    except KeyError:
        continue

# === Backtest each factor ===
def backtest_factor(factor_name):
    factor_returns = []
    for i, date in enumerate(factor_data.keys()):
        if date.month not in REBALANCE_MONTHS:
            continue
        df = factor_data[date].dropna()
        if len(df) < 10:
            continue

        top = df[factor_name].nlargest(int(len(df)*0.1)).index
        bottom = df[factor_name].nsmallest(int(len(df)*0.1)).index

        try:
            next_date = list(factor_data.keys())[i+1]
        except IndexError:
            break

        try:
            future_prices = monthly_prices.loc[next_date]
            curr_prices = monthly_prices.loc[date]

            top_ret = (future_prices[top] / curr_prices[top] - 1).mean()
            bottom_ret = (future_prices[bottom] / curr_prices[bottom] - 1).mean()
            factor_returns.append((next_date, top_ret, bottom_ret))
        except:
            continue

    df = pd.DataFrame(factor_returns, columns=["Date", "Top", "Bottom"]).set_index("Date")
    df["Top_Cumulative"] = (1 + df["Top"]).cumprod()
    df["Bottom_Cumulative"] = (1 + df["Bottom"]).cumprod()
    return df

# === Run backtests ===
factors = ['Size', 'Momentum', 'Volatility', 'Value', 'Growth']
results = {factor: backtest_factor(factor) for factor in factors}

# === Benchmark ===
benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
benchmark_ret = benchmark.pct_change().dropna()
benchmark_cum = (1 + benchmark_ret).cumprod()

# === Plot Streamlit Outputs ===
st.title("📈 Barra Factor Strategy Backtests")
for factor in factors:
    df = results[factor]
    st.subheader(f"{factor} Factor")
    st.line_chart(df[["Top_Cumulative", "Bottom_Cumulative"]].join(benchmark_cum.rename("Nifty 50"), how="inner"))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   2%|▏         | 1/50 [00:01<01:19,  1.62s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   4%|▍         | 2/50 [00:03<01:12,  1.51s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   6%|▌         | 3/50 [00:04<01:14,  1.59s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   8%|▊         | 4/50 [00:06<01:10,  1.54s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  10%|█         | 5/50 [00:07<01:07,  1.51s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  12%|█▏        | 6/50 [00:09<01:04,  1.47s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  14%|█▍        | 7/50 [00:10<01:06,  1.55s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  16%|█▌        | 8/50 [00:12<01:03,  1.51s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  18%|█▊        | 9/50 [00:13<01:01,  1.50s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  20%|██        | 10/50 [00:15<00:59,  1.49s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  22%|██▏       | 11/50 [00:16<00:57,  1.46s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  24%|██▍       | 12/50 [00:17<00:55,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  26%|██▌       | 13/50 [00:19<00:54,  1.48s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  28%|██▊       | 14/50 [00:20<00:47,  1.32s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  30%|███       | 15/50 [00:21<00:39,  1.13s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  32%|███▏      | 16/50 [00:22<00:41,  1.23s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  34%|███▍      | 17/50 [00:24<00:42,  1.28s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  36%|███▌      | 18/50 [00:25<00:42,  1.32s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  38%|███▊      | 19/50 [00:26<00:37,  1.21s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  40%|████      | 20/50 [00:28<00:40,  1.35s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  42%|████▏     | 21/50 [00:29<00:38,  1.31s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  44%|████▍     | 22/50 [00:30<00:37,  1.34s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  46%|████▌     | 23/50 [00:32<00:36,  1.37s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  48%|████▊     | 24/50 [00:33<00:35,  1.35s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  50%|█████     | 25/50 [00:34<00:34,  1.37s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  52%|█████▏    | 26/50 [00:36<00:33,  1.40s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  54%|█████▍    | 27/50 [00:37<00:28,  1.22s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  56%|█████▌    | 28/50 [00:38<00:28,  1.28s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  58%|█████▊    | 29/50 [00:39<00:27,  1.30s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  60%|██████    | 30/50 [00:41<00:28,  1.40s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  62%|██████▏   | 31/50 [00:43<00:27,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  64%|██████▍   | 32/50 [00:44<00:24,  1.37s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  66%|██████▌   | 33/50 [00:45<00:23,  1.35s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  68%|██████▊   | 34/50 [00:47<00:23,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  70%|███████   | 35/50 [00:48<00:21,  1.43s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  72%|███████▏  | 36/50 [00:49<00:19,  1.41s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  74%|███████▍  | 37/50 [00:51<00:18,  1.46s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  76%|███████▌  | 38/50 [00:52<00:16,  1.34s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  78%|███████▊  | 39/50 [00:54<00:15,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  80%|████████  | 40/50 [00:56<00:15,  1.52s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  82%|████████▏ | 41/50 [00:57<00:13,  1.49s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  84%|████████▍ | 42/50 [00:58<00:11,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  86%|████████▌ | 43/50 [01:00<00:10,  1.46s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  88%|████████▊ | 44/50 [01:02<00:09,  1.54s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  90%|█████████ | 45/50 [01:03<00:08,  1.61s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  92%|█████████▏| 46/50 [01:05<00:06,  1.57s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  94%|█████████▍| 47/50 [01:06<00:04,  1.55s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  96%|█████████▌| 48/50 [01:08<00:03,  1.59s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  98%|█████████▊| 49/50 [01:10<00:01,  1.60s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
# 100%|██████████| 50/50 [01:11<00:00,  1.43s/it]
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:43: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_prices = prices.resample('M').last()
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:109: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
# [*********************100%***********************]  1 of 1 completed
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\14217853.py:109: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 118
#     116 df = results[factor]
#     117 st.subheader(f"{factor} Factor")
# --> 118 st.line_chart(df[["Top_Cumulative", "Bottom_Cumulative"]].join(benchmark_cum.rename("Nifty 50"), how="inner"))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5767, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5636 def rename(
#    5637     self,
#    5638     mapper: Renamer | None = None,
#    (...)
#    5646     errors: IgnoreRaise = "ignore",
#    5647 ) -> DataFrame | None:
#    5648     """
#    5649     Rename columns or index labels.
#    5650
#    (...)
#    5765     4  3  6
#    5766     """
# -> 5767     return super()._rename(
#    5768         mapper=mapper,
#    5769         index=index,
#    5770         columns=columns,
#    5771         axis=axis,
#    5772         copy=copy,
#    5773         inplace=inplace,
#    5774         level=level,
#    5775         errors=errors,
#    5776     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:1132, in NDFrame._rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1125         missing_labels = [
#    1126             label
#    1127             for index, label in enumerate(replacements)
#    1128             if indexer[index] == -1
#    1129         ]
#    1130         raise KeyError(f"{missing_labels} not found in axis")
# -> 1132 new_index = ax._transform_index(f, level=level)
#    1133 result._set_axis_nocheck(new_index, axis=axis_no, inplace=True, copy=False)
#    1134 result._clear_item_cache()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6537, in Index._transform_index(self, func, level)
#    6535     return type(self).from_arrays(values)
#    6536 else:
# -> 6537     items = [func(x) for x in self]
#    6538     return Index(items, name=self.name, tupleize_cols=False)
#
# TypeError: 'str' object is not callable

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import linregress
from statsmodels.api import OLS, add_constant
import streamlit as st

# === Parameters ===
START_DATE = "2005-12-31"
END_DATE = "2025-07-31"
REBALANCE_MONTHS = [3, 6, 9, 12]  # Quarterly

# Step 1: Load NSE500 list
nse500 = pd.read_html("https://en.wikipedia.org/wiki/NIFTY_50", header=0)[1]
symbols = nse500['Symbol'].tolist()

# Step 2: Download adjusted close daily price history
data = {}
for symbol in tqdm(symbols):
    try:
        df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
        if df.empty or 'Close' not in df.columns:
            continue
        df = df[['Close']].rename(columns={'Close': symbol})
        data[symbol] = df
    except:
        continue

if not data:
    st.error("No data downloaded from yfinance. Check your internet connection or ticker symbols.")
    st.stop()

prices = pd.concat(data.values(), axis=1)
prices.columns = data.keys()

prices.index = pd.to_datetime(prices.index)
prices = prices.dropna(axis=1, how='all')

# === Calculate Barra-style factors ===
log_returns = np.log(prices / prices.shift(1))
monthly_prices = prices.resample('M').last()

factor_data = {}
for date in monthly_prices.index[12:]:
    try:
        current_prices = monthly_prices.loc[date]
        past_prices = monthly_prices.shift(12).loc[date]
        returns_12m = (current_prices / past_prices) - 1

        size = np.log(current_prices)
        momentum = returns_12m
        volatility = log_returns.loc[:date].rolling(252).std().loc[date]

        # Placeholder for value/growth (replace with real fundamentals later)
        value = pd.Series(np.random.normal(0, 1, len(current_prices)), index=current_prices.index)
        growth = pd.Series(np.random.normal(0, 1, len(current_prices)), index=current_prices.index)

        factors = pd.DataFrame({
            'Size': size,
            'Momentum': momentum,
            'Volatility': volatility,
            'Value': value,
            'Growth': growth
        })
        factor_data[date] = factors
    except KeyError:
        continue

# === Backtest each factor ===
def backtest_factor(factor_name):
    factor_returns = []
    for i, date in enumerate(factor_data.keys()):
        if date.month not in REBALANCE_MONTHS:
            continue
        df = factor_data[date].dropna()
        if len(df) < 10:
            continue

        top = df[factor_name].nlargest(int(len(df)*0.1)).index
        bottom = df[factor_name].nsmallest(int(len(df)*0.1)).index

        try:
            next_date = list(factor_data.keys())[i+1]
        except IndexError:
            break

        try:
            future_prices = monthly_prices.loc[next_date]
            curr_prices = monthly_prices.loc[date]

            top_ret = (future_prices[top] / curr_prices[top] - 1).mean()
            bottom_ret = (future_prices[bottom] / curr_prices[bottom] - 1).mean()
            factor_returns.append((next_date, top_ret, bottom_ret))
        except:
            continue

    df = pd.DataFrame(factor_returns, columns=["Date", "Top", "Bottom"]).set_index("Date")
    df.index = pd.to_datetime(df.index)
    df["Top_Cumulative"] = (1 + df["Top"]).cumprod()
    df["Bottom_Cumulative"] = (1 + df["Bottom"]).cumprod()
    return df

# === Run backtests ===
factors = ['Size', 'Momentum', 'Volatility', 'Value', 'Growth']
results = {factor: backtest_factor(factor) for factor in factors}

# === Benchmark ===
benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
benchmark_ret = benchmark.pct_change().dropna()
benchmark_cum = (1 + benchmark_ret).cumprod()

# === Plot Streamlit Outputs ===
st.title("📈 Barra Factor Strategy Backtests")
for factor in factors:
    df = results[factor]
    st.subheader(f"{factor} Factor")
    benchmark_cum_renamed = benchmark_cum.copy()
    benchmark_cum_renamed.name = "Nifty 50"
    combined = df[["Top_Cumulative", "Bottom_Cumulative"]].join(benchmark_cum_renamed, how="inner")
    st.line_chart(combined)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   2%|▏         | 1/50 [00:01<01:11,  1.46s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   4%|▍         | 2/50 [00:02<01:05,  1.36s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   6%|▌         | 3/50 [00:04<01:07,  1.43s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#   8%|▊         | 4/50 [00:05<01:03,  1.38s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  10%|█         | 5/50 [00:06<01:01,  1.36s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  12%|█▏        | 6/50 [00:08<01:03,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  14%|█▍        | 7/50 [00:09<01:02,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  16%|█▌        | 8/50 [00:11<00:59,  1.41s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  18%|█▊        | 9/50 [00:12<00:59,  1.46s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  20%|██        | 10/50 [00:14<00:57,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  22%|██▏       | 11/50 [00:15<00:55,  1.41s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  24%|██▍       | 12/50 [00:16<00:51,  1.35s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  26%|██▌       | 13/50 [00:18<00:50,  1.37s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  28%|██▊       | 14/50 [00:19<00:48,  1.35s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  30%|███       | 15/50 [00:20<00:40,  1.15s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  32%|███▏      | 16/50 [00:21<00:41,  1.23s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  34%|███▍      | 17/50 [00:23<00:44,  1.36s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  36%|███▌      | 18/50 [00:25<00:47,  1.48s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  38%|███▊      | 19/50 [00:26<00:41,  1.33s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  40%|████      | 20/50 [00:27<00:39,  1.31s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  42%|████▏     | 21/50 [00:28<00:40,  1.40s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  44%|████▍     | 22/50 [00:30<00:37,  1.36s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  46%|████▌     | 23/50 [00:31<00:40,  1.49s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  48%|████▊     | 24/50 [00:33<00:37,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  50%|█████     | 25/50 [00:34<00:35,  1.43s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  52%|█████▏    | 26/50 [00:36<00:34,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  54%|█████▍    | 27/50 [00:37<00:29,  1.26s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  56%|█████▌    | 28/50 [00:38<00:29,  1.32s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  58%|█████▊    | 29/50 [00:40<00:30,  1.46s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  60%|██████    | 30/50 [00:42<00:31,  1.56s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  62%|██████▏   | 31/50 [00:43<00:28,  1.48s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  64%|██████▍   | 32/50 [00:44<00:25,  1.42s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  66%|██████▌   | 33/50 [00:46<00:24,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  68%|██████▊   | 34/50 [00:47<00:22,  1.43s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  70%|███████   | 35/50 [00:49<00:22,  1.50s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  72%|███████▏  | 36/50 [00:50<00:20,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  74%|███████▍  | 37/50 [00:52<00:19,  1.48s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  76%|███████▌  | 38/50 [00:53<00:16,  1.38s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  78%|███████▊  | 39/50 [00:54<00:15,  1.41s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  80%|████████  | 40/50 [00:56<00:14,  1.45s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  82%|████████▏ | 41/50 [00:57<00:12,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  84%|████████▍ | 42/50 [00:59<00:11,  1.42s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  86%|████████▌ | 43/50 [01:00<00:09,  1.38s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  88%|████████▊ | 44/50 [01:01<00:08,  1.47s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  90%|█████████ | 45/50 [01:03<00:07,  1.47s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  92%|█████████▏| 46/50 [01:04<00:05,  1.44s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  94%|█████████▍| 47/50 [01:06<00:04,  1.43s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  96%|█████████▌| 48/50 [01:07<00:02,  1.42s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
#  98%|█████████▊| 49/50 [01:08<00:01,  1.39s/it]C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol + ".NS", start=START_DATE, end=END_DATE, interval="1d", progress=False)
# 100%|██████████| 50/50 [01:10<00:00,  1.41s/it]
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:43: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_prices = prices.resample('M').last()
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:110: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
# [*********************100%***********************]  1 of 1 completed
# C:\Users\amitt\AppData\Local\Temp\ipykernel_31168\2585672152.py:110: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   benchmark = yf.download("^NSEI", start=START_DATE, end=END_DATE, interval="1mo")["Close"].resample('M').last()
